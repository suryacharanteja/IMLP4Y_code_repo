# %%
import pandas as pd

# %%
FE_df = pd.read_excel("./FE_volvo.xlsx", sheet_name=)

# %%
FE_df
# Out:
#      Vehicle Total time (h)  Total distance (km)  Total fuel (l)  \
# 0     959483       21:03:00               319.44          425.25
# 1     959619       21:18:00               339.66          444.32
# 2     959959       20:48:00               346.57          444.42
# 3     960330       21:31:00               200.30          318.52
# 4     963913       21:14:00               200.68          278.55
# ..       ...            ...                  ...             ...
# 184   966290       20:06:00               514.41          394.76
# 185   966291       22:00:00               593.26          441.42
# 186   966292       21:36:00               554.04          428.40
# 187   966295       21:58:00               563.09          435.15
# 188   966296       22:16:00               592.34          465.97
#
#      Average fuel (l/100km)  Average AdBlue (l/100km)  \
# 0                    133.12                      0.00
# 1                    130.81                      0.00
# ...

# %%
FE_df.columns
# Out:
# Index(['Vehicle', 'Total time (h)', 'Total distance (km)', 'Total fuel (l)',
#        'Average fuel (l/100km)', 'Average AdBlue (l/100km)',
#        'Average speed driving (km/h)', 'Average brake counter (amount/100km)',
#        'Average stop counter (amount/100km)', 'PTO time', 'Idling time',
#        'Within economy time', 'Above economy time', 'Coasting time',
#        'Cruise control time', 'Vehicle overspeed (Fleet Limit)',
#        'Top gear time', 'Engine load time', 'Engine overrev time',
#        'Automatic time', 'Manual time', 'Power time', 'Low dist.',
#        'Medium dist.', 'Full dist.', 'Date'],
#       dtype='object')

# %%
FE_df["Average fuel (l/100km)"].mean()
# Out:
# 109.84169312169313

# %%
FE_df["Average fuel (l/100km)"].median()
# Out:
# 112.96

# %%
FE_df["Average fuel (l/100km)"].mode()
# Out:
# 0    116.56
# Name: Average fuel (l/100km), dtype: float64

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()
ax.hist(FE_df["Average fuel (l/100km)"])
plt.show()

# %%
FE_df.dtypes
# Out:
# Vehicle                                          int64
# Total time (h)                                  object
# Total distance (km)                            float64
# Total fuel (l)                                 float64
# Average fuel (l/100km)                         float64
# Average AdBlue (l/100km)                       float64
# Average speed driving (km/h)                   float64
# Average brake counter (amount/100km)             int64
# Average stop counter (amount/100km)              int64
# PTO time                                       float64
# Idling time                                    float64
# Within economy time                            float64
# Above economy time                             float64
# Coasting time                                  float64
# Cruise control time                            float64
# Vehicle overspeed (Fleet Limit)                float64
# Top gear time                                  float64
# ...

# %%
FE_df.isnull().sum()
# Out:
# Vehicle                                 0
# Total time (h)                          0
# Total distance (km)                     0
# Total fuel (l)                          0
# Average fuel (l/100km)                  0
# Average AdBlue (l/100km)                0
# Average speed driving (km/h)            0
# Average brake counter (amount/100km)    0
# Average stop counter (amount/100km)     0
# PTO time                                0
# Idling time                             0
# Within economy time                     0
# Above economy time                      0
# Coasting time                           0
# Cruise control time                     0
# Vehicle overspeed (Fleet Limit)         0
# Top gear time                           0
# Engine load time                        0
# Engine overrev time                     0
# Automatic time                          0
# Manual time                             0
# Power time                              0
# ...
